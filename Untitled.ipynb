# %%
5+3
# Out:
# 8

# %%
import simplejson as json
from matplotlib import pyplot as plt 
from langdetect import detect
import re
import pandas as pd 
import numpy as np 
import seaborn as sns
import string
import nltk
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)



test = pd.read_csv('7282_1.csv')
test.head(2)
# Out:
#                   address categories      city country   latitude  longitude  \
# 0  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
# 1  Riviera San Nicol 11/a     Hotels  Mableton      US  45.421611  12.376187
#
#                  name postalCode province          reviews.date  \
# 0  Hotel Russo Palace      30126       GA  2013-09-22T00:00:00Z
# 1  Hotel Russo Palace      30126       GA  2015-04-03T00:00:00Z
#
#       reviews.dateAdded  reviews.doRecommend  reviews.id  reviews.rating  \
# 0  2016-10-24T00:00:25Z                  NaN         NaN             4.0
# 1  2016-10-24T00:00:25Z                  NaN         NaN             5.0
#
#                                         reviews.text  \
# 0  Pleasant 10 min walk along the sea front to th...
# 1  Really lovely hotel. Stayed on the very top fl...
#
#                         reviews.title reviews.userCity reviews.username  \
# 0  Good location away from the crouds              NaN      Russ (kent)
# 1      Great hotel with Jacuzzi bath!              NaN       A Traveler
#
#   reviews.userProvince
# 0                  NaN
# 1                  NaN

# %%
print(test.shape)
test.keys()
hotels=test[['name','reviews.date','reviews.rating','reviews.text']].drop_duplicates()
print(hotels.shape)

#hotels.reset_index()
hotels.reset_index(drop=True)
# Out:
# (35912, 19)
# (35733, 4)
#                                                 name          reviews.date  \
# 0                                 Hotel Russo Palace  2013-09-22T00:00:00Z
# 1                                 Hotel Russo Palace  2015-04-03T00:00:00Z
# 2                                 Hotel Russo Palace  2014-05-13T00:00:00Z
# 3                                 Hotel Russo Palace  2013-10-27T00:00:00Z
# 4                                 Hotel Russo Palace  2015-03-05T00:00:00Z
# ...                                              ...                   ...
# 35728                             Elk Springs Resort  2012-03-20T00:00:00Z
# 35729                             Elk Springs Resort  2012-03-12T00:00:00Z
# 35730                             Elk Springs Resort  2015-11-03T00:00:00Z
# 35731  Extended Stay America Grand Rapids - Kentwood                   NaN
# 35732  Extended Stay America Grand Rapids - Kentwood                   NaN
#
#        reviews.rating                                       reviews.text
# 0                 4.0  Pleasant 10 min walk along the sea front to th...
# 1                 5.0  Really lovely hotel. Stayed on the very top fl...
# 2                 5.0  Ett mycket bra hotell. Det som drog ner betyge...
# 3                 5.0  We stayed here for four nights in October. The...
# 4                 5.0  We stayed here for four nights in October. The...
# ...               ...                                                ...
# 35728             5.0  Best of the Best!!!! My family and I stayed in...
# 35729             5.0  Amazing Vacation in Beautiful Cabin We stayed ...
# 35730             5.0  My husband and I stayed at Tree Tops which is ...
# 35731             0.0  to share your opinion of this businesswith YP ...
# 35732             0.0         xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
# [35733 rows x 4 columns]

# %%
#hotels['tidy_tweet'] = hotels['reviews.text'].str.replace("[^a-zA-Z#]", " ")
#hotels.head(100)
# Out:
#                                                  name          reviews.date  \
# 0                                  Hotel Russo Palace  2013-09-22T00:00:00Z
# 1                                  Hotel Russo Palace  2015-04-03T00:00:00Z
# 2                                  Hotel Russo Palace  2014-05-13T00:00:00Z
# 3                                  Hotel Russo Palace  2013-10-27T00:00:00Z
# 4                                  Hotel Russo Palace  2015-03-05T00:00:00Z
# ..                                                ...                   ...
# 95                                     Comfort Suites  2016-06-04T00:00:00Z
# 96    Thunderbird Executive Inn and Conference Center  2009-04-06T00:00:00Z
# 97                            Little Belt Inn Neihart                   NaN
# 98                            Little Belt Inn Neihart                   NaN
# 99  Hawthorn Suites By Wyndham Livermore Wine Country  2015-04-17T00:00:00Z
#
#     reviews.rating                                       reviews.text  \
# 0              4.0  Pleasant 10 min walk along the sea front to th...
# 1              5.0  Really lovely hotel. Stayed on the very top fl...
# 2              5.0  Ett mycket bra hotell. Det som drog ner betyge...
# 3              5.0  We stayed here for four nights in October. The...
# 4              5.0  We stayed here for four nights in October. The...
# ..             ...                                                ...
# 95             3.0  We stayed here because of a family medical eme...
# 96             3.0  This is the old address for Thunderbird. The n...
# 97             0.0  to share your opinion of this businesswith YP ...
# 98             0.0         xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 99             3.0  The room was fine and the mattress was very co...
#
#                                            tidy_tweet
# 0   Pleasant    min walk along the sea front to th...
# 1   Really lovely hotel  Stayed on the very top fl...
# 2   Ett mycket bra hotell  Det som drog ner betyge...
# 3   We stayed here for four nights in October  The...
# 4   We stayed here for four nights in October  The...
# ..                                                ...
# 95  We stayed here because of a family medical eme...
# 96  This is the old address for Thunderbird  The n...
# 97  to share your opinion of this businesswith YP ...
# 98         xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 99  The room was fine and the mattress was very co...
#
# [100 rows x 5 columns]

# %%
hotels=hotels.dropna()
hotels['tidy_tweet'] = hotels['reviews.text'].str.replace("[^a-zA-Z#]", " ")
hotels['name'] = hotels['name'].str.replace("Hotel", "")

#hotels.head(100)
hotels['tidy_tweet'] = hotels['reviews.text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
#df['subject acc.ver'] = df['subject acc.ver']
hotels.head()
# Out:
#             name          reviews.date  reviews.rating  \
# 0   Russo Palace  2013-09-22T00:00:00Z             4.0
# 1   Russo Palace  2015-04-03T00:00:00Z             5.0
# 2   Russo Palace  2014-05-13T00:00:00Z             5.0
# 3   Russo Palace  2013-10-27T00:00:00Z             5.0
# 4   Russo Palace  2015-03-05T00:00:00Z             5.0
#
#                                         reviews.text  \
# 0  Pleasant 10 min walk along the sea front to th...
# 1  Really lovely hotel. Stayed on the very top fl...
# 2  Ett mycket bra hotell. Det som drog ner betyge...
# 3  We stayed here for four nights in October. The...
# 4  We stayed here for four nights in October. The...
#
#                                           tidy_tweet
# 0  Pleasant walk along front Water Bus. restauran...
# 1  Really lovely hotel. Stayed very floor were su...
# 2  mycket hotell. drog betyget fick under taksarn...
# 3  stayed here four nights October. hotel staff w...
# 4  stayed here four nights October. hotel staff w...

# %%
#tokenized_tweet = hotels['tidy_tweet'].apply(lambda x: x.split())
#tokenized_tweet.head()
l1=[]
hotels['tokenized_tweet'] = hotels.apply(lambda x: x['tidy_tweet'].split(),axis=1)
#hotels['tokenized_tweet'] = hotels['tidy_tweet'].apply(lambda x: x.split())
#hotels['tokenized_tweet'].head()
hotels.head()
# Out:
#             name          reviews.date  reviews.rating  \
# 0   Russo Palace  2013-09-22T00:00:00Z             4.0
# 1   Russo Palace  2015-04-03T00:00:00Z             5.0
# 2   Russo Palace  2014-05-13T00:00:00Z             5.0
# 3   Russo Palace  2013-10-27T00:00:00Z             5.0
# 4   Russo Palace  2015-03-05T00:00:00Z             5.0
#
#                                         reviews.text  \
# 0  Pleasant 10 min walk along the sea front to th...
# 1  Really lovely hotel. Stayed on the very top fl...
# 2  Ett mycket bra hotell. Det som drog ner betyge...
# 3  We stayed here for four nights in October. The...
# 4  We stayed here for four nights in October. The...
#
#                                           tidy_tweet  \
# 0  Pleasant walk along front Water Bus. restauran...
# 1  Really lovely hotel. Stayed very floor were su...
# 2  mycket hotell. drog betyget fick under taksarn...
# 3  stayed here four nights October. hotel staff w...
# 4  stayed here four nights October. hotel staff w...
#
#                                      tokenized_tweet
# 0  [Pleasant, walk, along, front, Water, Bus., re...
# 1  [Really, lovely, hotel., Stayed, very, floor, ...
# 2  [mycket, hotell., drog, betyget, fick, under, ...
# 3  [stayed, here, four, nights, October., hotel, ...
# 4  [stayed, here, four, nights, October., hotel, ...

# %%
"""from nltk.stem.porter import *
stemmer = PorterStemmer()
#stemming
hotels['stemming'] = hotels['tokenized_tweet'].apply(lambda x: [stemmer.stem(i) for i in x])
hotels.head()"""
tokenized_tweet = hotels['tidy_tweet'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [Pleasant, walk, along, front, Water, Bus., re...
# 1    [Really, lovely, hotel., Stayed, very, floor, ...
# 2    [mycket, hotell., drog, betyget, fick, under, ...
# 3    [stayed, here, four, nights, October., hotel, ...
# 4    [stayed, here, four, nights, October., hotel, ...
# Name: tidy_tweet, dtype: object

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

hotels['tokenized_tweet'] = hotels['tokenized_tweet'].apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
hotels['tokenized_tweet'].head()
# Out:
# 0    [pleasant, walk, along, front, water, bus., re...
# 1    [realli, love, hotel., stay, veri, floor, were...
# 2    [mycket, hotell., drog, betyget, fick, under, ...
# 3    [stay, here, four, night, october., hotel, sta...
# 4    [stay, here, four, night, october., hotel, sta...
# Name: tokenized_tweet, dtype: object

# %%
# Python program to demonstrate the 
# use of join function to join list 
# elements with a character. 


#hotels['tokenized_tweet'] = hotels['tokenized_tweet'].apply(lambda x: [' '.join(tokenized_tweet[i]) for i in x]) # stemming
for i in range(0,20):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])

hotels['tidy_tweet'] = tokenized_tweet
hotels['tidy_tweet'].head()
print(tokenized_tweet[0])
# Out:
# P                                                               l                                                               e                                                               a                                                               s                                                               a                                                               n                                                               t                                                                                                                               w                                                               a                                                               l                                                               k                                                                                                                               a                                                               l                                                               o                                                               n                                                               g                                                                                                                               f                                                               r                                                               o                                                               n                                                               t                                                                                                                               W                                                               a                                                               t                                                               e                                                               r                                                                                                                               B                                                               u                                                               s                                                               .                                                                                                                               r                                                               e                                                               s                                                               t                                                               a                                                               u                                                               r                                                               a                                                               n                                                               t                                                               s                                                                                                                               e                                                               t                                                               c                                                               .                                                                                                                               H                                                               o                                                               t                                                               e                                                               l                                                                                                                               c                                                               o                                                               m                                ...

# %%
d={'val':[1,1,1]}
dd=pd.DataFrame(d)
#dd
dd['new']=5
dd.apply(lambda x : x[0]+100,axis=0)
#dd
# Out:
# val    101
# new    105
# dtype: int64

# %%
# Python program to demonstrate the 
# use of join function to join list 
# elements without any separator. 

# Joining with empty separator 
list1 = ['g','e','e','k', 's'] 
print("".join(list1)) 

# Python program to demonstrate the 
# use of join function to join list 
# elements with a character. 

list2 = [1,2,3,4] 

s = " "

# joins elements of list1 by '-' 
# and stores in sting s 
s = s.join(list2) 

# join use to join a list of 
# strings to a separator s 
print(s)
# Out:
# geeks
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-ed8edc13db0d> in <module>
#      17 # joins elements of list1 by '-'
#      18 # and stores in sting s
# ---> 19 s = s.join(list2)
#      20
#      21 # join use to join a list of
#
# TypeError: sequence item 0: expected str instance, int found
